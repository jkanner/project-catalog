'LDC0009955665', 'LDC0009969701', 'LDC0009971796', 'LDC0009986545', 'LDC0009992135', 'LDC0010046479', 'LDC0010055167', 'LDC0010059921', 'LDC0010072631', 'LDC0010077307', 'LDC0010130536', 'LDC0010135951', 'LDC0010145201', 'LDC0010152045', 'LDC0010189078', 'LDC0010193736', 'LDC0010214406', 'LDC0010249182', 'LDC0010260736', 'LDC0010263188', 'LDC0010265214', 'LDC0010271905', 'LDC0010294060', 'LDC0010309429', 'LDC0010325067', 'LDC0010349152', 'LDC0010370346', 'LDC0010370837', 'LDC0010380359', 'LDC0010395164', 'LDC0010398209', 'LDC0010399619', 'LDC0010404697', 'LDC0010420454', 'LDC0010436089', 'LDC0010447287', 'LDC0010460630', 'LDC0010489676', 'LDC0010497882', 'LDC0010530940', 'LDC0010534240', 'LDC0010547492', 'LDC0010564733', 'LDC0010571618', 'LDC0010581749', 'LDC0010589321', 'LDC0010611636', 'LDC0010617506', 'LDC0010648732', 'LDC0010650557', 'LDC0010661113', 'LDC0010674216', 'LDC0010690380', 'LDC0010695903', 'LDC0010699134', 'LDC0010720157', 'LDC0010750009', 'LDC0010768439', 'LDC0010775630', 'LDC0010792563', 'LDC0010873206', 'LDC0010883656', 'LDC0010890257', 'LDC0010894555', 'LDC0010898907', 'LDC0010943886', 'LDC0010973953', 'LDC0010986205', 'LDC0010988871', 'LDC0011012716', 'LDC0011031391', 'LDC0011042611', 'LDC0011068046', 'LDC0011082504', 'LDC0011086446', 'LDC0011101379', 'LDC0011106360', 'LDC0011147872', 'LDC0011154147', 'LDC0011154331', 'LDC0011199102', 'LDC0011223050', 'LDC0011229087', 'LDC0011235980', 'LDC0011239622', 'LDC0011245686', 'LDC0011253640', 'LDC0011254295', 'LDC0011255417', 'LDC0011263148', 'LDC0011267357', 'LDC ...

# %% [markdown]
# ### Create a `GalacticBinary` object from one of the filenames
# * This will load in data for candidate injections and the posterior samples

# %%
gb = GalacticBinary.load_feather(names[19])
# Out:
# Loaded LDC0005441002 with 2069 samples and 1 candidates.

# %% [markdown]
# * Use `gb.subset_candidates` and `gb.subset_samples` to get the galactic binary parameters only
# * Otherwise, you'll have all the parameters (including `Name`, `SNR`, and so on)

# %%
print(gb.candidates.loc[gb.candidates.index[0], 'SNR'])
# Out:
# 57.236235961898664

# %%
hdr_df = pd.read_feather("../data/hdrs.feather")

# %%
def plot_bad_hdrs(bad_hdr_index, hdr_threshold, hdr_df):
    hdr_threshold = 0.9

    bad_hdrs = hdr_df[hdr_df["8D HDR"] >= hdr_threshold]
    gb = GalacticBinary.load_feather(bad_hdrs.iloc[bad_hdr_index]["Name"])

    # get the candidate that is associated with this particular entry
    candidate_name = bad_hdrs.iloc[bad_hdr_index]["Candidate"]
    candidate_index = gb.candidates[gb.candidates["Name"] == candidate_name].index[0]

    if (candidate_name - gb.candidates.iloc[candidate_index]["Name"] != 0):
        # check that the candidate is correct
        # this shouldn't happen
        raise ValueError("Candidate name does not match the one in the gb.candidates dataframe")

    gb.corner_plot(candidate_index)

# %%
plot_bad_hdrs(bad_hdr_index=45, hdr_threshold=0.9, hdr_df=hdr_df)
