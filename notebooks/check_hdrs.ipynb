# %%
import glob
from project_catalog.galactic_binary import GalacticBinary
from project_catalog.match_injections import get_all_matches
import pandas as pd
import numpy as np

# %%
hdrs = pd.read_feather('../data/hdrs.feather')

# %%
matches = get_all_matches(hdrs, threshold=0.89)
# Out:
# 0it [00:00, ?it/s]
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 matches = get_all_matches(hdrs, threshold=0.89)
#
# File ~/Documents/lisa/project-catalog/src/project_catalog/match_injections.py:16, in get_all_matches(hdrs, threshold)
#      14 for i, name in tqdm(enumerate(names)):
#      15     matches[name] = []
# ---> 16     gb = GalacticBinary.load_feather(name)
#      17     for injection_index in range(len(gb.injections)):
#      18         if check_injection_match(gb, injection_index, hdrs, threshold=threshold):
#
# File ~/Documents/lisa/project-catalog/src/project_catalog/galactic_binary.py:67, in GalacticBinary.load_feather(cls, name, posterior_dir, injections_dir)
#      65 # Wrap the polarization angle of injections to be between 0 and pi (to match chain prior)
#      66 injections_df = wrap_polarization_angle(injections_df)
# ...

# %%
files = glob.glob('../data/injection_matches/*.feather')

# %%
names = get_galactic_binary_names()
detected = []
not_detected = []

detected_sl = []
not_detected_sl = []

threshold = 0.95

median_chain_snrs = []
for i, name in enumerate(names):
    gb = GalacticBinary.load_feather(name)
    for candidate_index in range(len(gb.injections)):
        if check_injection_match(gb, candidate_index, hdrs, threshold=threshold):
            detected.append(i)
        else:
            not_detected.append(i)
        if check_sky_location_support(gb, candidate_index, hdrs, threshold=threshold):
            detected_sl.append(i)
        else:
            not_detected_sl.append(i)
# Out:
# Loaded LDC0023810973 with 2013 samples and 1 candidates.
# Loaded LDC0041226577 with 4309 samples and 1 candidates.
# Loaded LDC0030125413 with 3666 samples and 3 candidates.
# Loaded LDC0039987364 with 2141 samples and 1 candidates.
# Loaded LDC0030205330 with 3670 samples and 1 candidates.
# Loaded LDC0036346646 with 2442 samples and 1 candidates.
# Loaded LDC0032702190 with 3198 samples and 1 candidates.
# Loaded LDC0039519357 with 2405 samples and 1 candidates.
# Loaded LDC0026590928 with 4759 samples and 1 candidates.
# Loaded LDC0042955643 with 4369 samples and 2 candidates.
# Loaded LDC0035013982 with 3352 samples and 1 candidates.
# Loaded LDC0046959142 with 4295 samples and 1 candidates.
# Loaded LDC0044144804 with 4993 samples and 1 candidates.
# Loaded LDC0033825064 with 4757 samples and 1 candidates.
# Loaded LDC0026240217 with 1605 samples and 1 candidates.
# Loaded LDC0052790217 with 2666 samples and 1 candidates.
# ...

# %%
print(len(detected))
print(len(not_detected))
print(len(detected_sl))
print(len(not_detected_sl))
# Out:
# 8059
# 8269
# 10780
# 5548

# %%
print(len(detected))
print(len(not_detected))
print(len(detected_sl))
print(len(not_detected_sl))
# Out:
# 7677
# 8651
# 11518
# 4810

# %%
len(names)
# Out:
# 12390

# %%
values, counts = np.unique(detected, return_counts=True)

# %%
len(np.where(counts>1)[0])
# Out:
# 25

# %%
values, counts = np.unique(detected_sl, return_counts=True)

# %%
len(np.where(counts>1)[0])
# Out:
# 566
